# %% [markdown]
# # Assignment 13 The last but not the least : RNN
#
# The idea behind RNNs is to make use of sequential information. In a traditional neural network we assume that all inputs (and outputs) are independent of each other. But for many tasks that’s a very bad idea. If you want to predict the next word in a sentence you better know which words came before it. RNNs are called recurrent because they perform the same task for every element of a sequence, with the output being depended on the previous computations. Another way to think about RNNs is that they have a “memory” which captures information about what has been calculated so far. In theory RNNs can make use of information in arbitrarily long sequences, but in practice they are limited to looking back only a few steps (more on this later). Here is what a typical Vanilla RNN looks like:

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://miro.medium.com/max/4000/0*WdbXF_e8kZI1R5nQ.png", width=700)
# Out:
# <img src="https://miro.medium.com/max/4000/0*WdbXF_e8kZI1R5nQ.png" width="700"/>

# %% [markdown]
# In this, we will not work on images for more simplicity. Instead of that, let's be generative on text, no? One of the classical application of RNN network is to be able to predict the next value given a certain amount of older one. Compare to the previous network, you give t word ($x_t$) and the network output you $x_{t+1}$ (here it's $h_t$)

# %%
Image(url= "https://iq.opengenus.org/content/images/2019/12/1_XvUt5wDQA8D3C0wAuxAvbA.png", width=700)
# Out:
# <img src="https://iq.opengenus.org/content/images/2019/12/1_XvUt5wDQA8D3C0wAuxAvbA.png" width="700"/>

# %% [markdown]
# By doing so, could it be able to train a network to be able to write something? Let's try to make a Siliconspears. In the data folder, you have now a shakespear folder containing all the work of William. Your task will be to implement a RNN who learn how to write some shakespear! (it will just sham of course).
#
# Bellow, you will find all the utilitary code to be able to perform it. The Corpus class is a dataset and you can call a batch with the target by applying get_batch to a batchifyed dataset

# %%
import torch
import torch.nn as nn
import torch.autograd as autograd
import torch.cuda as cuda
import torch.optim as optim
import torch.nn.functional as F
import os
import tqdm
import numpy as np

# %%
class Dictionary(object):
    def __init__(self):
        self.word2idx = {}
        self.idx2word = []

    def add_word(self, word):
        if word not in self.word2idx:
            self.idx2word.append(word)
            self.word2idx[word] = len(self.idx2word) - 1
        return self.word2idx[word]

    def __len__(self):
        return len(self.idx2word)


class Corpus(object):
    def __init__(self, path):
        self.dictionary = Dictionary()
        
        # This is very english language specific
        # We will ingest only these characters:
        self.whitelist = [chr(i) for i in range(32, 127)]
        
        self.train = self.tokenize(os.path.join(path, 'train.txt'))
        self.valid = self.tokenize(os.path.join(path, 'valid.txt'))

    def tokenize(self, path):
        """Tokenizes a text file."""
        assert os.path.exists(path)
        # Add words to the dictionary
        with open(path, 'r',  encoding="utf8") as f:
            tokens = 0
            for line in f:
                line = ''.join([c for c in line if c in self.whitelist])
                words = line.split() + ['<eos>']
                tokens += len(words)
                for word in words:
                    self.dictionary.add_word(word)

        # Tokenize file content
        with open(path, 'r',  encoding="utf8") as f:
            ids = torch.LongTensor(tokens)
            token = 0
            for line in f:
                line = ''.join([c for c in line if c in self.whitelist])
                words = line.split() + ['<eos>']
                for word in words:
                    ids[token] = self.dictionary.word2idx[word]
                    token += 1

        return ids
    
def batchify(data, batch_size):
    # Work out how cleanly we can divide the dataset into bsz parts.
    nbatch = data.size(0) // batch_size
    # Trim off any extra elements that wouldn't cleanly fit (remainders).
    data = data.narrow(0, 0, nbatch * batch_size)
    # Evenly divide the data across the bsz batches.
    data = data.view(batch_size, -1).t().contiguous()
    if cuda.is_available():
        data = data.cuda()
    return data

def get_batch(source, i, evaluation=False):
    seq_len = min(bptt_size, len(source) - 1 - i)
    data = Variable(source[i:i+seq_len], volatile=evaluation)
    target = Variable(source[i+1:i+1+seq_len].view(-1))
    if cuda.is_available():
        data = data.cuda()
        target = target.cuda()
    return data, target

# %%
#corpus = Corpus('./shakespear')

# %%
# !wget "https://www.dropbox.com/s/st67040zaw8fs4e/train.txt?dl=0"

# !ls
# Out:
# --2020-02-12 19:58:45--  https://www.dropbox.com/s/st67040zaw8fs4e/train.txt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.7.1, 2620:100:601b:1::a27d:801
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.7.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/st67040zaw8fs4e/train.txt [following]
# --2020-02-12 19:58:45--  https://www.dropbox.com/s/raw/st67040zaw8fs4e/train.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc50872e72e7927c307f604fc25c.dl.dropboxusercontent.com/cd/0/inline/Ax8A4PqqZqNyFwshCIxrWfJ2FZw8EsSNd5WaTY3rv5X3MpGUGN7629suAB-3nREVRN7UsaVTs82UCW_lNR92piT4ARt_b-Bqad0aEAgYqC1mtIgTuQx-yDJaEeSQYVH-Ync/file# [following]
# --2020-02-12 19:58:45--  https://uc50872e72e7927c307f604fc25c.dl.dropboxusercontent.com/cd/0/inline/Ax8A4PqqZqNyFwshCIxrWfJ2FZw8EsSNd5WaTY3rv5X3MpGUGN7629suAB-3nREVRN7UsaVTs82UCW_lNR92piT4ARt_b-Bqad0aEAgYqC1mtIgTuQx-yDJaEeSQYVH-Ync/file
# Resolving uc50872e72e7927c307f604fc25c.dl.dropboxusercontent.com (uc50872e72e7927c307f604fc25c.dl.dropboxusercontent.com)... 162.125.3.6, 2620:100:601b:6::a27d:806
# Connecting to uc50872e72e7927c307f604fc25c.dl.dropboxusercontent.com (uc50872e72e7927c307f604fc25c.dl.dropboxusercontent.com)|162.125.3.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5359853 (5.1M) [text/plain]
# Saving to: ‘train.txt?dl=0’
#
# train.txt?dl=0      100%[===================>]   5.11M  --.-KB/s    in 0.1s
#
# 2020-02-12 19:58:46 (37.8 MB/s) - ‘train.txt?dl=0’ saved [5359853/5359853]
#
#  sample_data  'train.txt?dl=0'

# %%
"""vocab = len(corpus.dictionary)
print(vocab)
n_hidden = 100
n_layers = 2
batch_size = 100
"""
# Out:
# 'vocab = len(corpus.dictionary)\nprint(vocab)\nn_hidden = 100\nn_layers = 2\nbatch_size = 100\n'

# %%
# Switched to character based RNN, ´cause we know how :D

path_to_file = './train.txt?dl=0'
text = open(path_to_file, encoding='utf-8').read()

print(text[0:2500])
# Out:
# THE SONNETS
#
#                     1
#
# From fairest creatures we desire increase,
# That thereby beauty’s rose might never die,
# But as the riper should by time decease,
# His tender heir might bear his memory:
# But thou contracted to thine own bright eyes,
# Feed’st thy light’s flame with self-substantial fuel,
# Making a famine where abundance lies,
# Thy self thy foe, to thy sweet self too cruel:
# Thou that art now the world’s fresh ornament,
# And only herald to the gaudy spring,
# Within thine own bud buriest thy content,
# And, tender churl, mak’st waste in niggarding:
#   Pity the world, or else this glutton be,
#   To eat the world’s due, by the grave and thee.
#
#
#                     2
#
# When forty winters shall besiege thy brow,
# And dig deep trenches in thy beauty’s field,
# Thy youth’s proud livery so gazed on now,
# Will be a tattered weed of small worth held:
# Then being asked, where all thy beauty lies,
# Where all the treasure of thy lusty days;
# To say, within thine own deep sunken eyes,
# Were an all-eating shame, and thriftless praise.
# How much more praise deserv’d thy beauty’s use,
# If thou couldst answer ‘This fair child of mine
# Shall sum my count, and make my old excuse,’
# Proving his beauty by succession thine.
#   This were to be new made when thou art old,
#   And see thy blood warm when thou feel’st it cold.
#
#
#                     3
#
# Look in thy glass and tell the face thou viewest,
# Now is the time that face should form another,
# Whose fresh repair if now thou not renewest,
# Thou dost beguile the world, unbless some mother.
# For where is she so fair whose uneared womb
# Disdains the tillage of thy husbandry?
# Or who is he so fond will be the tomb
# Of his self-love to stop posterity?
# Thou art thy mother’s glass and she in thee
# Calls back the lovely April of her prime,
# So thou through windows of thine age shalt see,
# Despite of wrinkles this thy golden time.
#   But if thou live remembered not to be,
#   Die single and thine image dies with thee.
#
#
#                     4
#
# Unthrifty loveliness why dost thou spend,
# Upon thy self thy beauty’s legacy?
# Nature’s bequest gives nothing but doth lend,
# And being frank she lends to those are free:
# Then beauteous niggard why dost thou abuse,
# The bounteous largess given thee to give?
# Profitless usurer why dost thou use
# So great a sum of sums yet canst not live?
# For having traffic with thy self alone,
# Thou of thy self thy sweet self dost deceive,
# Then how when nature calls thee to be gone,
# What acceptable audit canst thou leave?
#   Thy unused beauty must

# %%
# The unique characters in the file
vocab = sorted(set(text))
print ('{} unique characters'.format(len(vocab)))
# Out:
# 90 unique characters

# %%
# Creating a mapping from unique characters to indices
char2idx = {u:i for i, u in enumerate(vocab)}
text_as_int = np.array([char2idx[c] for c in text])

# Create a mapping from indices to characters
idx2char = np.array(vocab)

# %%
def one_hot_encode(arr, n_labels):
    # Initialize the the encoded array
    one_hot = np.zeros((np.multiply(*arr.shape), n_labels), dtype=np.float32)

    # Fill the appropriate elements with ones
    one_hot[np.arange(one_hot.shape[0]), arr.flatten()] = 1.

    # Finally reshape it to get back to the original array
    one_hot = one_hot.reshape((*arr.shape, n_labels))

    return one_hot

# %%
def get_batches(arr, batch_size, seq_length):
    '''Create a generator that returns batches of size
       batch_size x seq_length from arr.

       Arguments
       ---------
       arr: Array you want to make batches from
       batch_size: Batch size, the number of sequences per batch
       seq_length: Number of encoded chars in a sequence
    '''

    batch_size_total = batch_size * seq_length
    # total number of batches we can make
    n_batches = len(arr) // batch_size_total

    # Keep only enough characters to make full batches
    arr = arr[:n_batches * batch_size_total]
    # Reshape into batch_size rows
    arr = arr.reshape((batch_size, -1))

    # iterate through the array, one sequence at a time
    for n in range(0, arr.shape[1], seq_length):
        # The features
        x = arr[:, n:n + seq_length]
        # The targets, shifted by one
        y = np.zeros_like(x)
        try:
            y[:, :-1], y[:, -1] = x[:, 1:], arr[:, n + seq_length]
        except IndexError:
            y[:, :-1], y[:, -1] = x[:, 1:], arr[:, 0]
        yield x, y

# %%
train_on_gpu = torch.cuda.is_available()
print ('Training on GPU' if train_on_gpu else 'Training on CPU')
# Out:
# Training on GPU

# %%
class VanillaCharRNN(nn.Module):
    def __init__(self, vocab, n_hidden=256, n_layers=2,
                 drop_prob=0.5, lr=0.001):
        super().__init__()
        self.drop_prob = drop_prob
        self.n_layers = n_layers
        self.n_hidden = n_hidden
        self.lr = lr
        self.vocab = vocab
        
        '''TODO: define the layers you need for the model'''
        #self.input_layer = nn.Linear(n_hidden + len(vocab), n_hidden)
        self.rnn = nn.RNN(len(vocab), n_hidden, n_layers, batch_first=True)
        #self.hidden_layer = nn.Linear(n_hidden, len(vocab))
        #self.softmax = nn.LogSoftmax(dim=1)
        
        self.fc = nn.Linear(n_hidden, len(vocab))

    def forward(self, x, hidden):
        '''TODO: Forward pass through the network
        x is the input and `hidden` is the hidden/cell state .'''

        
        #x_cat = torch.cat((x, hidden), 1)
        #hidden_t = self.hidden_layer(x_cat)
        #out = self.softmax(x_cat)
        
        #for h in hidden:
            #print(h.shape)
        
        #for h in hidden:
         #   hidden_t = torch.stack(hidden, dim=0)
        
        #hidden_t = torch.stack(hidden) 
        #print(hidden.shape)
        #print(x.shape)
        #out, hidden_t = self.rnn(x, hidden)
        
        #out = self.fc(out[:, -1, :])
        #print(out)
        
        hidden_t = torch.stack(hidden) # convert tensor tuple to hidden tensor
        
        if (train_on_gpu):
            hidden_t = hidden_t.cuda()
            x = x.cuda()
        
        out, hidden_t = self.rnn(x, hidden_t)
        out = self.fc(out)
        
        
        # return the final output and the hidden state
        return out, hidden_t

    def init_hidden(self, batch_size):
        ''' Initializes hidden state '''
        
        hidden = torch.zeros(self.n_layers, batch_size, self.n_hidden)

        return hidden

# %%
def train(model, data, epochs=10, batch_size=10, seq_length=50, lr=0.001, clip=5, val_frac=0.1, print_every=10):
    ''' Training a network

        Arguments
        ---------

        model: CharRNN network
        data: text data to train the network
        epochs: Number of epochs to train
        batch_size: Number of mini-sequences per mini-batch, aka batch size
        seq_length: Number of character steps per mini-batch
        lr: learning rate
        clip: gradient clipping
        val_frac: Fraction of data to hold out for validation
        print_every: Number of steps for printing training and validation loss

    '''
    model.train()

    opt = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()

    # create training and validation data
    val_idx = int(len(data) * (1 - val_frac))
    data, val_data = data[:val_idx], data[val_idx:]

    if (train_on_gpu):
        model.cuda()

    counter = 0
    n_vocab = len(model.vocab)
    for e in range(epochs):
        # initialize hidden state
        h = model.init_hidden(batch_size)
        #print(h.shape)
        
        '''TODO: use the get_batches function to generate sequences of the desired size'''
        dataset = get_batches(data, batch_size, seq_length)

        for x, y in dataset:
            counter += 1

            # One-hot encode our data and make them Torch tensors
            x = one_hot_encode(x, n_vocab)
            inputs, targets = torch.from_numpy(x), torch.from_numpy(y)

            if (train_on_gpu):
                inputs, targets = inputs.cuda(), targets.cuda()

            # Creating new variables for the hidden state, otherwise
            # we'd backprop through the entire training history
            h = tuple([each.data for each in h])
            
            #h_state = torch.tensor([h[0][0]], [h[1]])
            #print(x.shape)
            
            #if (train_on_gpu):
            #    h = (h.cuda())

            # zero accumulated gradients
            model.zero_grad()
            
            '''TODO: feed the current input into the model and generate output'''
            output, h = model(inputs, h)
            
            flat_targets = targets.view(500)
            flat_output = output.view(-1, len(vocab))
            
            #print(flat_targets.shape)
            #print(flat_output.shape)

            '''TODO: compute the loss!'''
            loss = criterion(flat_output, flat_targets)
            
            # perform backprop
            loss.backward()
            # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
            nn.utils.clip_grad_norm_(model.parameters(), clip)
            opt.step()

            # loss stats
            if counter % print_every == 0:
                # Get validation loss
                val_h = model.init_hidden(batch_size)
                val_losses = []
                model.eval()
                for x, y in get_batches(val_data, batch_size, seq_length):
                    # One-hot encode our data and make them Torch tensors
                    x = one_hot_encode(x, n_vocab)
                    x, y = torch.from_numpy(x), torch.from_numpy(y)

                    # Creating new variables for the hidden state, otherwise
                    # we'd backprop through the entire training history
                    val_h = tuple([each.data for each in val_h])

                    inputs, targets = x, y
                    if (train_on_gpu):
                        inputs, targets = inputs.cuda(), targets.cuda()

                    '''TODO: feed the current input into the model and generate output'''
                    output, val_h = model(inputs, val_h)
                    
                    flat_targets_val = targets.view(500)
                    flat_output_val = output.view(-1, len(vocab))
                    
                    '''TODO: compute the validation loss!'''
                    val_loss = criterion(flat_output_val, flat_targets_val)

                    val_losses.append(val_loss.item())

                print("Epoch: {}/{}...".format(e + 1, epochs),
                      "Step: {}...".format(counter),
                      "Loss: {:.4f}...".format(loss.item()),
                      "Val Loss: {:.4f}".format(np.mean(val_losses)))
                
                '''TODO: sample from the model to generate texts'''
                input_eval = 'E'
                print(sample(model, 1000, prime=input_eval, top_k=10))
                
                model.train()  # reset to train mode after iterationg through validation data

# %%
def predict(model, char, h=None, top_k=None):
    ''' Given a character, predict the next character.
        Returns the predicted character and the hidden state.
    '''
    #print('char: ' + str(char))
    #print('char_idx: ' + str(char2idx[char]))
    # tensor inputs
    
    x = np.array([[char2idx[char]]])
    x = one_hot_encode(x, len(model.vocab))
    inputs = torch.from_numpy(x)

    if (train_on_gpu):
        inputs = inputs.cuda()

    # detach hidden state from history
    h = tuple([each.data for each in h])
    '''TODO: feed the current input into the model and generate output'''
    output, h = model(inputs, h) # TODO

    # get the character probabilities
    p = F.softmax(output, dim=-1).data
    if (train_on_gpu):
        p = p.cpu()  # move to cpu

    # get top characters
    if top_k is None:
        top_ch = np.arange(len(model.vocab))
    else:
        p, top_ch = p.topk(top_k)
        top_ch = top_ch.numpy().squeeze()

    # select the likely next character with some element of randomness
    p = p.numpy().squeeze()
    char = np.random.choice(top_ch, p=p / p.sum())

    # return the encoded value of the predicted char and the hidden state
    return idx2char[char], h

# %%
def sample(model, size, prime='The', top_k=None):
    if (train_on_gpu):
        model.cuda()
    else:
        model.cpu()

    model.eval()  # eval mode

    # First off, run through the prime characters
    chars = [ch for ch in prime]
    h = model.init_hidden(1)
    for ch in prime:
        char, h = predict(model, ch, h, top_k=top_k)

    chars.append(char)

    for ii in range(size):
      '''TODO: pass in the previous character and get a new one'''
      char, h = predict(model, chars[-1], h, top_k=top_k)
      chars.append(char)

    model.train()
    return ''.join(chars)

# %%
''''TODO: Try changing the number of units in the network to see how it affects performance'''
n_hidden = 256
n_layers = 2

vanilla_model = VanillaCharRNN(vocab, n_hidden, n_layers)
print(vanilla_model)
# Out:
# VanillaCharRNN(
#   (rnn): RNN(90, 256, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=256, out_features=90, bias=True)
# )

# %%
''''TODO: Try changing the hyperparameters in the network to see how it affects performance'''
batch_size = 10
seq_length = 50
n_epochs = 5  # start smaller if you are just testing initial behavior

# %%
train(vanilla_model, text_as_int, epochs=n_epochs, batch_size=batch_size, seq_length=seq_length, lr=0.001, print_every=1000)
# Out:
# Epoch: 1/5... Step: 1000... Loss: 1.9334... Val Loss: 2.0892
# Exs, bertes this spear.
#   ORTINSORD IO. Ind wall,
# What be dice on wricce thy hish wit dowerer
#     The as, tent a ware appere,
#     Throw if son lough, and sigh all sime a dray, with thoo arath this changels and hit stricincands carned; in more, and buce;
#     Tue thank ind the she seick.
#   SIATROSANI CIUSTAN. I wis ditk amo,
#     But der why paed in ord wo the hit so thinglerdes appear'd, inlent on pry this parit one this a this so pranty
#     Wet the wan a trease,
#     So to mare som stall a danger thy thime wrytire ill bust mikes, my terer worthelt to and har beant the man seling to throm core, me a stound thath
#     And a mer sheast be ngalk.
#                                                                                                                                                   [Oxiuris thou,
#     This; and hank.
#     TAxtun with sterent be mas athime,
#     The bith nom he tall servite
# Singene, and as frall insa tincont in ofrodt.
#   ETEMEN. Sone that besing and the way,
#
# To shourd my t
# Epoch: 1/5... Step: 2000... Loss: 1.7349... Val Loss: 1.9582
# ENGUR.
# I have.
#
# GRUMISSBERLE.
# Mane his werled'd, and a from in
#     A be his hid
# ’ather he with on thering antwell't;
# And meavlinings when miscellemed. Whill much breathan houth thou have and forthy, therefoor thee
#     In to be do had I saint of her mustore, it of the forleesion.
#
#
# WARLER]
#
# SATE HESTRON].
# Gud whlle spook.
#     To mister. Be in sumiof am an oft,
#                   Exeumt, him, my this heart,
#     Andandies off that a promptry.
#    ALONT
#   I’ll have theises, and thou will anowell, thee frow and in her wase
#     And that ie how, sulvess.
#  KA.
# IN OF ROUN POUTOSICENNTRENCE.
#   GRUVIO.
# Witle, in he come, berede,
#   A divily toor offented to thunglemas; wedce hath hath their pridess this,
# And their him tince
#     Amporaly cupponatest.
#
#              BEATRO.
#
# To fed hath the worce herse shill him word our catsers falterow;
#     And to cerace.
#
# GUCENCLANTZ. Nare, I, and there to sear his shall his death
#     And his hand; and since hem endicing,
#     Learil with me sencendow;
#     And thin I t
# Epoch: 1/5... Step: 3000... Loss: 1.5558... Val Loss: 1.9080
# ENG.
# Or sent, hen is the mently not this hath now with thee
#
# ALIOL. Bet see the pers'el obedyer?
#   KING EDRANWARD. Bear I pertain to me to being mesiel,
#     Let I swark stail moth are slees, and friends, this deed he distician, swort be follow a sue late,
# To lest, I, my masate. So their thou madien'd hen sprangly sir,
#     Fash of’el her own the most all mest true
#     As made a proud of my more and serven are tire.
#
# ADTIPHOSUCELDEL.
#       My gentle I thange and all this honous.
#
# FEERE. Well sun that is this down
# We stull de thing hees, frother me to thy mading mad a sable me.
#   BOLINGBROKE. Yet my fatle what nonet irfeer.
#
#
#       EXENER. Iysty a said.
#     Whithoul with this are thyer him.
#
#
#       CONROLIO.
#       What I may I wood me, my stram to they?
#     In this soul a chasun and the due a this thing
#     I tay all thank whem I have, to thy speation is seis'd!
#   BOONTAR. I shall and tell with the claught
#       nave this all for mine you wheng them indeed it thee,
#     That you store will a
# Epoch: 1/5... Step: 4000... Loss: 1.4864... Val Loss: 1.8818
# ENGHORD._]
#
# KING.
#       Yet; the Duke of you self
#    wording self enter and seeds.
#
#
#       DUKETHERDEL.
# A sall._]
#
#
#  [_Till, you sound brace upon that he was terms as a maither's
#     and let.
#
#
#       LEANCELOW, and
#       Thou best that here. He hal stay on you, han of a speek, and
#     Herrant.
#
#  SEBAST.
# Leech me be my feat.
#
# LEARET.
# Till mencure the master hithild farty to boun wny tolds in that Is whou tell theirst of a partion
#     But to them
#     The Duke
#   MANDIUS. Here matus his heart,
#     Whye hoplest._
#
# KENT.
# Is is
#     Myself you trould my monness; I will says.
#   DUOFIT. A myink, and the Delly shall thee, with a should this dare to me.
#     It it says hall.
#   KENT.
# This the fare whom whenks of herry tell.
#
#               Anoching. And mysperted
#      [IS dening take.
#
#
#       LEONSAMOLI, Marning you ardowing of the stays fare and let
#     Which is ancher's the mind, was to sturd. Himsel'd, and a sterning; hare the like well with them tweep. When I war it wises, hear was hell the warken;
# Epoch: 1/5... Step: 5000... Loss: 1.4401... Val Loss: 1.8480
# Ex.
# Neven me to back your housh, my lording fleself of that beadings and paliant flade to the
#     trie cruech as those have bows.
#
# FrANTHSMY. Fars wouldst ciench any tilt to herily be stiple of thas the mestent honour who away.' wealing here.
#
#                Exit BESTRAGENENERIG.
# When be the prowimaler thereford, and come, sir, who courtest thin peecuntand tognort power on me,
#     For show is all prince
# Rispiscasters, and assion,
# I’ll do he hearty of yet your haster'st trights,
# One sich worty,
#     To brealon; had all be great is bain me the can ot;
#     Firnow the garless, and hidrement healtr,
#     For I do tend the like a princuse fought the housdario,
#     Thou bear age, then belied abodie thousailst me on these pace
#     From sheech mettenian and cannot was presention.]
#     Fronoul frayous in his hearts and world wither's still by my live heress'd
#     Why dear thore the should speak, and sick him; and stand batis,
#     Alences!
#
# [Rin Jano owarded them hose!
#     There’s dustic and breads f
# Epoch: 1/5... Step: 6000... Loss: 1.4311... Val Loss: 1.8496
# ENNZOSTESS. There I still you, with here are yourself,
#     Sufferiens
#     When I was he sine shild turm, If this discrince
#  and peace well-
#     Fo him to heaven thou him fath hers, to tall of sect
#     Of here is in your; thanks.
#   POMPEMAN. What can as thy law, with
#                                  Exit
#   ANMENNES. Well, as witnous after thou will. Nay.
#     Is these fell'd, farry,
#     Mark thinvering.
#     I should noted infeat there douth, as my, I have notest with while a father are thou none?
#   ELIUCI. Suctrespereng thing of fear aspeids thee?
#   STEPH.
# Tare so nothing so loagured of fear-now.
#   ENOZATO. I am I am never pany him so mank, and so lords.
#   FIRST LORD. If I womp, away, I’ll puse with speak at with a couser.
#   FIRST LORD. Shald your leave, then loring of your lash, which, it.                                         [Go, which a huve here will atserv'd there brook,
#     Alard to you,
#     She pley mights; for I creed you park.. Thrise this purmings a marring an our will I and,
#
# Epoch: 1/5... Step: 7000... Loss: 1.5943... Val Loss: 1.8370
# ERSHANT. AL, WOLSAT
#   AMBARITON of Calis,
# And histand in arms others the stay abbay are mine as their sould
#     His come hard hold but shouth fortuning his pard the peast to me abter tord out that time,
#     Where his talk adiel we him the sittle thy chood, siskly should swift blood.
#     Sors, Itherple attend that made hold how
#     Have ass the
#   five is so, aftiess.
#   AMNICOND SOMPTON
#
#   PORTIM. I drye field tell that, as you,
#     Which all to cutient heart, his fartings, for I ambition. BADYORY. But thou diglos; and not fiel of a stinked; heart that traities his pastian for hard
#     To cants the formo and mer his heart that heaven then. I willows beep
#     As me.
#     Out, I heart of the folly with the subrear of a father of thousand, hath to the book'd in an her.
#   ARINOUS. At hench the trote at I shall the most pars
#     Welcow, and the bring most as fearing so look- tere, his son and splare,
#     And the brance as this speak. I dave son my grocked'd and love.
#   FORD. He have har that tho
# Epoch: 1/5... Step: 8000... Loss: 1.4638... Val Loss: 1.8125
# ERD.BONTUS
#
# HUMIEN. And whose merry me, my fremants. Shear you the lady to highness,
#     Thou are thou whatenard in elained issumes and thy curest by the counded.
#   LAVINIUS.
#     Y.                                     I’ll as an that is no mind in the such anour,
#     What has a stul state is a glaise, my lord, mady heaven scalm
#     Of all thee affected sinks many, shall he din as all
#     The will,
#     An anch it aching and such faring this heard
#     That lattle is herets hand,
# I hear with hear thee for a
#   speaker steed me and a first brath out honeuns
#     On a sir,
#     What ad muchsome treak hands thas I hear now, and
#     That the hare to thee from free, thy mighted make my lieging; for at a hunchess to his court offly.
#
#                        Exeunt; Caesar’s tuck sund him: after like you, that’s me
# O more will be so, when she solded men,
#     But har, sir.
#     No; what yet that you and asing too and as see.
#   KING PENATHAS
#     If when yem in a winge of that be answello! Hences tongue t
# Epoch: 1/5... Step: 9000... Loss: 1.5065... Val Loss: 1.7969
# ERGUS. This poisone thousand.
#     This part a house.                   Rese for your grace:
# And that sumbrew. He shalt sons to subbortested beggase and with than demethion death.
#   BOY. O go,s the discosidence any hands
#     Here and well be range, for washe
#     Here,
#     To thee not fiering the heaven's the
#     spipider dispatch of a foillity!
#     Thou think have dast the soon happ'ry say
#     I am the King widner of my tarkirs?
#   GEOR. That to you curning and werrias show
#     But she say at let our counterorast,
#     There in tigh a goversed in more.
#   TIMOWER. I shall nob in thy pride, and firedom a were newel him, sir, were heaven with them?
#
#   GUIDERIUS. And thou thy beeds stand here our spieres his bove to her;
#     Or his and thy heart.
#
# LARISAN. The sword, put it? Ladainor palace
#     Say ne ensere against of me heaven;
#     Then seck, when they to the compiclast hand.
#     O prays. Here’s appects of the demest cannous beastle him the land. Are shall by my decking atselve shopt them swe
# Epoch: 2/5... Step: 10000... Loss: 1.6028... Val Loss: 1.8044
# ENDY.
# He is a paper thy fattes, they had woe
#     The shall dismberech all make to can, I have him
#     This make out than hath such offect, nother, sit
#     Hash not should not there's day,
#          Than stum dead.
#     Is that I sir.
#     You shalt your lowe my complial's foot.
#     But I sove yours is not stop age.
#   BELANIO. The day.
#     The most close by dead!
#
#   MENCE. Now I should die; hath been and my shaperate;
#     As where so do the words him not seties.
#   DEMETRIUS and I wall;
#     And though I have, that I a wends to decio, sir? Nay,
#     The must that we may streed; and shall most store hers, but
#     Upon unage one my head a time he show,
# And say three my swars and has mad I park'd
#     Umiluress his him; you harst me.
#     How when that seesed with a tright,
#     And think
#     And I doth their say but he was numped we
#     singly the too.
#   LYSALIT Or't blood,
# Orciasol by he hat dost the chreves withous of houses
#     Was some as not those thou holy down than thee,
#     And he hath cast
# Epoch: 2/5... Step: 11000... Loss: 1.5754... Val Loss: 1.7838
# ExS.
# As me hear, what's a mark, but and before me,
#     But before to scirin to her heard see
#     To me invenge.
#     A porroniar of the see,
#     Which bear me their worth.
#     But, my lord, and have to be a being. And mot,
#   But leared that me thou send, but all the wrong
#           this is but him as we serming-old,
#     Seem to drout of brriful.
#
# POLONIUS.
# Ourned hamp to make mean for our exglimy how leftines and wise, would be said
#     To spended and whom shalty are them out,
# In mus dream of our land,
# And but beaud with thee her, hught, and to mad to spake mine bly-claw,
# O shall's hear and askandly swear,
# Blained, sporth beauty; I hall hearly servant to trackeds a mastered heard we how the will,
#                           Enter GAUNTH
#
#                   Enter Gloss fare madry this bur acheath.
#     Well, as thee did to lik, sir, we bring in a forth.m
#     And to died with leftires him my shame to mine off,
#     And body before by man to speaks beseech
#
#   ANGELO. I'll lays. He he say born be
# Epoch: 2/5... Step: 12000... Loss: 1.4034... Val Loss: 1.7800
# ERDY.
# Good ball, and brave my curpers, with defirdled with therefores too.
#     That in but ter termeds wooking, bid yet for me.
#
# PLESENG. Yet seek of the most daughter, have to dead so.
# ADRIANA. What well supp and what make me were was my busine.
#     If the tender the come the poor; though to die. They dight so? Yet no every all my part you to her them with this bass;
#     Wherein the masters she wherein the medally.
#
#                                           Exeunt PEOLOS. I am I candin'd, who cannot.
#
# KING.
# I sents ond a stranger's like a sucterity will be so place with all thee.
#     Now have if your hearts tend up to hot.
#     And and morning that. What was the father in your master, fain servanger.
#     We'll stolour.
#
#                                                                         Exin, my sake, words you will seem.
#   MESTERS.
# Noters'd and be so here's deliv'd his head.
#
# PETRUCHIO.
# What!' our most tuil the beaust, that.
#   LUCTINGBRAYERING.
# What good sick, to trusces, to that ma
# Epoch: 2/5... Step: 13000... Loss: 1.4373... Val Loss: 1.7805
# Ex]
# If you will be not all thine and done telect.
#   SECOND GENTLEMAN. See, he chink here.
#
# ROGHERRWALDOSSENGENER. Such o'ercose shall tell
#     To bold and till seen, when boy;
#     Why love, sin, but is tell of our head;
#     Stedy the sweet on it,, laughter fool, band
#     What take yed whicce do stil to this-wind a have nothing.
#     The heaveness, if a proclait all seces of thee, servess
#     A proud he'r perial; I am heaviest with such a late,
#     To here, as this.
#                    Re-enter Rome means,
#     Follows all and which my face, to beggire it; whiles. There
#     away. I am a sheder then; hand that I am fulst.
#   COUNTESS or to speak than I peated
#     Thereader thy but hears for his bloody-their secured meed here all, and my faulthing-besterarch
#     Off wood what man me stay. By it. Ay the lossing act
#     Were was are severeighness, sweed have all heaven.
#   FLUELLEN. So dispatting. Is destreen!
#
# GENTLEMAN.
# If here he do but heart; he will
#     With his hand the sea,s true of thy his
# Epoch: 2/5... Step: 14000... Loss: 1.4368... Val Loss: 1.7706
# ENNOUS.
# I have, sir; in his be to-daughter will my chide them first for themself,
#     And make our leg; amplister.
#
# GENTLEMAN.
# Ay you drings over true; wife me worthyont
#     May storn'd!
#   BUCKINGHAMTOCK
#
#                                               Enter thee fell'd by that if your
#     beatont my conteary and thy prophes
#     Freeth to campet.
#   MESSINIUS. But, if I do sweet.
#     How shy serio sorrow for the sadies;
#     Will sel them; I would never welt brought his cours,
#     Frulted on stream, which I'll dispreserves ond show
#     The worth, I call it follow'd by what you mountrece
#     They act.
#     If I wounds, I will give your past
#
# Enter-Corroll'd to do now that which in son,
#     For that my barn's motter, in allipious
#     The law your courge my life bite
#
#     They worthing soldied; sleep my mouth so fursty.
#   CALESAN. My lords fair'd our father.
#   MENTER. Thou hast so lover bling my foaloy, with younged; some poot our dittle wonted perfortuoth; and
#     before the King,
# Wear suit'd t
# Epoch: 2/5... Step: 15000... Loss: 1.5213... Val Loss: 1.7942
# EDGUN
#
#   CLEBEYM. My shalleth my tidet hurlity and time stakes better
#     That you will have signes, my lord, you arm of thee madably doeb, I'll spirits a witness,
#     Traito, high spiten!]
#   BURGUNEY. If you a stopless,
#     All thouse of your man bounds! Sigre, wherein I mysh to him the gods, and have sime.
#     And stafs is mads, that my lord; she stronk?
#     And hand, for your looks may for me.
#                                                           Eetellass his lovers this brift
#      the day! There strifor of your lort? Why, tell these a state our sleepy the bond abream than more by thes
#     English- as you stand' in sworn anyth,
#     Will have such this my lord?
#   MALCRAS. Speak my stath thy hoartizars; bate of hand? By lott blario's aboots a kear.
#
#
#                Ere make a strikg in the fil with me to his galsed
#     That doth to make in that I do name, say I say here stir bred
# to above star I am I should I mudning!     ancuty is his back
#     That hath honour in the strange on, t
# Epoch: 2/5... Step: 16000... Loss: 1.4919... Val Loss: 1.7837
# ERDER. I shall be burd
#     To bov'd me.
#
#                                                                   Exeunt IV OFFFLANI. Of out it whose;
#     I'll betwnet fare one thy gluck; but it, truly by
#     the King still attroul browns,
#     The sour onterning one increath witness,
#     To himself; but sir; and I dear it behind
#     Than this! and the laint being in bross to him to old see you spury you behold,
#     The strulle throother.
#
# FALSTAFF. Ay and shown and beat as you.                                            Enter MILUINGARIT
#
#   TALLANE. Stry not so friends and thus hither but or intend you that have sech, becrue in his bonds.
#     If with all hot she is alls so my safoor
#     That stresses and may, arm's mustils of my honour;
# Seer not a think the prose more he hot shorth by of a hughly that I hope
#     That husw thy complint speak a tearing the time
#     But shall this name in our facters;
#     Nor head his hossor'd? Condith you, I will to your prote
# A pare to drunk the King it?
#   CASCI
# Epoch: 2/5... Step: 17000... Loss: 1.4682... Val Loss: 1.7839
# Ex]1
#
# ACT_4|SC_15
#     I. Tilles, to dreams a malice it follow's; have behalls.
#   PRINCESS OF FRANCE. And Ifberation sear
#     To first for your mind; but he is sweet,
#     That half answer with a false send be, marget, well substandly-
# a slecked, and she have soldiers the paliciless born she is deed
#   Cassious; but I pray happy,
#     Sweet. He.
#   PRINCESS OF FRANCE. Sevular man.                                                                 Me and Mischar you he as the can doest this some seeks,
#     Well, the bigst, and the from the burnine than with poise of your speece
#
#   DUMOLLIA.                 The gener woman?- Her wook at learnester, then, be much
#     To me. Tribunal from fames they compers the great last but works
#     The sight held' was not been breather’d too can this time you as the ball'd
#     A carping brabe, for my feast slait
#   BUTER. To strike the but it, former wife on my challor,
#     O, then for, by the consaght; will not lanted. He hath leave it to this, and the grown and
# Epoch: 2/5... Step: 18000... Loss: 1.2713... Val Loss: 1.7588
# ExS.
# Flat it.
#   HOST. The fixted thy fladge his guited
#     As taib for the was now, I decovereen him than here althement
#     With one tortune tow so most of threat
#     The forten missall;
#     While he halfet, he conjoy'd boud falsestion
# Him hath slament satit speak at my sing.
#
# PERICLES.
# Have it shall preserve me that hath
#     Thou sheets and load these much.
#   THIRD KING JOHN. Ay, who but you some for the fath you.
#   FALSTAFF. Nay the bound alracking that thou desacts to
#     And hath hither my lords, a like bectars
#     And may not tears and give him britence,
#     Sweet his poers of their faith, and the companius
#     To make it in the things
#     Than yet not see, never malice.
#     Shall poother that he cane and chances, but shair need
#     That have her, my both.
#
# PERICLES.
# Not be charge and so but tie itle,
#     And fear he hath die, for him, hust none slay you
#     so. Hirds for the pacties thought,
#     Have subjects, fler friends;
#     Why the more to see say as the west,
#     We comes the
# Epoch: 2/5... Step: 19000... Loss: 1.4900... Val Loss: 1.7506
# ESS.
# To come. He breath to do, marry, strangla, and let
#     To wares to thee?
#
# MARON.
# What sin. But in the frestress, to be a peace.
#   SAY. A hail to him.
#     The noush, bring wither.
#   FIRST GUBE. There’s her breaking that doubties me.
#   ROSALAREN.
# Narn stafory and his body comport
#     He will be find,
#     Tramentray, but in a littlest
#     Froms and were do with his soul
#     To see, he hast not walk sons and angwargs; and at me of your being many cut
# Upon a fearing, and was must, bid a mode.
#   CAESAR. Some thou did a deemfush to my heart
#     To could he there is well; for were, or arms;
#     Soon silvarys of yorressal with at madam.
#   SAYRA.
# Where’s manquet in hellush, then their spreat,
#     With first war of ship the stopp'd.
#
# BATON.
# How down him are back, will light hard,
#     Sing by warling and cleans in the like two mine;
#     But of the bosom her luse of chasking his main is done.
#   PENERIUS. Say him is well draw now.
#
# BOULT.
# Fareward and sorrow her banks, beside, and thou come with
# Epoch: 3/5... Step: 20000... Loss: 1.3633... Val Loss: 1.7368
# ERSTARY.
# We power suffirs friend tealing have not,
# For I fields in disgains:
#     From thee are, to before the hold but and day. I’ll
#     The find the house wavers so, and the crown
# That it time dream, I lov'st me?
#
# LUCENTIO.
# Dow too such merrifids born and beaf me thee too?
#     Cailors indeed of you.
#   CASSIUS. Caesar is if I wold which to say I am. Har and spiritust be
# Sole to thee, I had no two woo’s at offer them.
#   PAGE.
# That two some suppess to the lustion, and the thanks
# That it that have befuly it an indarre of free wim blood it.
#   MARSTER. No, and blood, this fill.
#
# GRUMIO.
# This is bids faumift of than he stoe, and fashing.
#     Since where sisters._]
#
# FIRST OFFLIECH. And that I’ll be sudder discore before set healtress;
#     To some winstration of mine.
#
#   LANGBROKE.
# A cause the weak it not.
#
#                                          DOOMALIA.
#     That as my wear against some they found
# What shall forch been form stold. I deserved,
#     In the forgives his beauting me.
#   PORTIMAS.
# T
# Epoch: 3/5... Step: 21000... Loss: 1.6185... Val Loss: 1.7616
# ENGERO..
#
# HORTENSIO.
# There is take my with my wife that he way; be hath not hath my lead is so truit, swear and time.
#   LUCIUS. Save you with a drupy since; and you are arms
#     There is a poor that?
#   LUCIUS. I am see the my prosted in one
#     By you aratious?
#     With stull the huck, will not sick!
#     The doormoull on their mine of two whores in our spitios.
#
# LUCENDY. Who, what she itself, and harmy a sweet satis.
#     Love, henry monstar a deck in thee, and, than me for thy merride,
#     Let is tiers, through me for that
#      these dear himself, whereads to my prediors
#     I have mistrust, and these britains of death and make my lord?
#   SERVANT. Well hard he will splunge to mard of the pity hath there more other will.
#   FLUELANUS. I put this decreature to the states;
#     It is duicord,
#     Then I'll more that seen he do then war, brincisforation of a will and strong?
#
#
#       LEONAND. I will less is days,
#   So will thy fair sweet in the humlion?
#   CLAUDIO.
#       Where common of seem, an
# Epoch: 3/5... Step: 22000... Loss: 1.3423... Val Loss: 1.7637
# ExENSTERN. From I come of
# twometh man. Butifle of this,
#     But thou done about to do not will neable
# Atteat'd of this father: thou may to his truspene,
#       not carpey, by your most water
#     Bote score, I condy suctsad perfock, and see their father bodies
#     Thou know me, my merchaner may dright him writ.
#
# O GEWER. Not home ind overamined fince,
# Bet like follow with one that work with him to more man!
#     If he prece you be mother is man, with the poor hole.
#
# QUEEN.
# So, have men, stack, he will be cap in my person
# Anable suppose midst, by my noubt,
#     Bet make them hither? Wondred my public way, much think your own life,
# Who sin, from these witch was his hundred, meet to my pat him
#     To him think to dring, the corver what your part forgh.            [Diven of that currius man?
# CONG OF ESOL. Thy high may hence,
#     When men’s abrain,
#     And are not fail some sans anyth this assure me.
#
#                                         How thee hither he say or secret to his hand
#     So how
# Epoch: 3/5... Step: 23000... Loss: 1.2743... Val Loss: 1.7721
# EDGEN.
#       So into be assure of those from
#           Have your sim. Why, I am closered the budeding buiden
#     Her he all differth every shoutd unto.
# Or but now we would not belive it.
#   MERBY. I honged is wine, no, my lord, their drived wears and deapings
#     Our point in your swald or with the powired him suit to broked to th' sail for ede
#     And that will sons by the comfeigne,
#     Or wossack appear of yourself,
#          Exeunt
#
# SCENE Varatio,
#     Would marted.
#     This stid the firther, take a son of th' most in his beards?
#                 Exeuster, and a libe
#     Woman to be that wag them he wour in lords, what I hidseen my father alone
#     Mark, a state and lay them, indeather in his daughter, I.
#   SIRVIUS. My toubled well in they cardine;
#     And husband if he was no mine and then I would not murds was your end we wast
#     Here they are i' th' horses attended;
# Which this danered of his day!
#     He's not beason tempossiblething
#     How lains oul deserve he cousach
#     A going, a
# Epoch: 3/5... Step: 24000... Loss: 1.3451... Val Loss: 1.7594
# ESS. Why, in that complamer than the
# corms, sit out my hollance is trame me freed hit secret,
#     In what tell there, I that I cannot command's embly sea and be means and state. Well band no boot. Have as no more deather, well?
#   PAROLLER. Well, I will his for thy corfly above mury heir more
#     Have bound, nor to desire of my great of shook how it is' while,
#     Tyn bade me how dout men of law and wife, go to strumsels;
#                               Enter GLOUCESTER. How, a kind him-away. Is me and soul, most man.
#
#   MAStER. So nite and with steal it is th' still help it is, give them to thee!
#   BASTINT. I am look their sound blame two CORIOLANUS.                                                                                                         The shall be a thrive, is my holy at enemied his dispatier
#     And set is all their
#     I precene to be toot his fear
# To have neither and trimil't. What. There, been into, I know you
#     That comes in them, to true meast.     good master.
#
#
# Epoch: 3/5... Step: 25000... Loss: 1.3707... Val Loss: 1.7804
# ExEUS. We must he speach.
#                                 Exeun three humbly! When as much far mousa
#     As all't does throughts of ho!
#   QUEEN, when you a sing
#     When I am an office to you.
#   QUEENT
#
#                Enter ANTTAMER'S SERVANT
#   LORENZO. How willow'd me, the common shall the light;
#     I am solates, and against metions,
#     He in a ships of grave the pow'rit shall see
#     Till me for wises banque and all out
#     On the deny inday our eye,
#     I shall he has of horse.
#     What sliphs'll have all will not make
#     Had a gently dogue, if shall be a comment of,
#     In to'll hours so beghally, be all and much of fly
#     And sad the be midst, and how wonly being,
#     In our pluce are shall deader treams
#
#           Exit PAGE. How makes to her, well.
#   FIRLUS
#
#   MENOCHESS
#     I before he devill,
# Bid a would do against this an all.
#   LUCINE GENTLEMAN. Who warry it.
#   AUMENTUS. Why, here at marries is going
#     If noble, and the wind o'er I to but tell,
# A dead against holy, I am a
# Epoch: 3/5... Step: 26000... Loss: 1.4061... Val Loss: 1.7689
# ENTHERERA, JAQUESS
# AUFFORD. So much sworn meet by trumpet and marry,
#     Who says you, lady?
#     His father and let me between,
# And there ours of our brave way
#     Towd make much or the house.
#   SECOND. Most and true, I have me send his
#     Till I would having and dismires of thee
#     To confected on th' acquainted
#   Master my means, thou in his meaning words? It well.
#     If thy minure more doth my sister?
#   CLEOPATRE
#   DECHIER
#
#   ANTONY. A market be me, that we shall
#     Who be times a much to brow you
#     mean but i’ the sword at ever all of Walfserer. He by and this?
#   CLEOPATRA BEROWE STEPHER. Hang or the sea of a shoel and maid by his lumsed in the great
#
#   KING HENRY. That wassion's tell if that the piting by them as in thee!
#     In my britaste itsels, whet miet of but will
#     A parest makes to him?
#   KING JESS. I kind but mightst thy hells, and slaves affects,
#     And sens to curse it my barge tells
#     A grow of madies of Compents will!
#     As thou do carland tell me that think
# Epoch: 3/5... Step: 27000... Loss: 1.4629... Val Loss: 1.7494
# ERD.
#   FALSTAFF. And wound;
#     And nothing for your brave serve the friend,
#     She she comes the hours of he will art time,
#     It; so speak id torcumer abour with his state
#
#        Ere the witchress an hour age. I am to with morrow his criple wite anon them answer fair a faith;
# And you, take think well at. The stur'd stand bad wear the thanks heaven, well and seek thee bed abave this will so bown
#
# Ander to murderity.
#
# JULIET.
# Fair flunchest been-some prepary.
#   DUMAINS.
# This hourn of serve of thou concestes
#     Stainst are-wid speak all that?
#     Some soul, the true feasted to sad;
#     And we will no true of her worthies home.                     And wit,
#     I hear against to times or her thought
# To miscellest as to smy the side and together’s thought
#     tell it out of heavy to hang thy father horess
#     I will husband these chleage man the sorry. And I be some
#     that I should stuly
#     heaven to accountless strung way:
#     Which the day that we both, will not the mine; inviot the
# Epoch: 3/5... Step: 28000... Loss: 1.4881... Val Loss: 1.7400
# ERSTARDIRAND.
# That; friend, and ather purportain with a fare
# Live, by unfearned sain and heath how somorth with streng.
#   THIRD LORDS.
# Wo alone with me, which a more wreths writ.
#   HUBERT OF Famary, a thousfurable he din.
#
# JULIET.
# Whither lie form of the poisonore of wreat is not,
#     And with transt the fools; where heard that with
#     To makes a man otheralded
#   TAUBET, and BELARIUS, father?
#   MACDESTER. So that these a consceflets
#
# Now' is a mother we must weak in my troag the suit
#     To she with all would as feel as the which with the weat of ald
#     In the whither she their dropaning-dgeed at her weep their daughter;
#     But suild thee, shall, and here obtys
#
#   SHALLOW. It is not her caster; and
#     Shind it devil, and her that your masire,
#     Nighlesh'd wert feerful to smakes forchuond the King.
#
#  BENELER. Therefools alorms,
#     How walk in the forests.
#   MACCUTIUS Lord of feeling to be my how lady;
#     My disconceits their mistress? What, and the mulit off he doubt you.
#     A fr
# Epoch: 4/5... Step: 29000... Loss: 1.4344... Val Loss: 1.7337
# ENSS. [Alore thing.
#   BELDUMELAND
#
# Tay, tell, too misfuct thou say'st a last:
# The tide to was not conquy, from those faster.
# If deceive, whom through the postard forgive thine offer there
#  was he that what bur awaken, and the sport.
#
# PERICLES.
# Purren but a miscorm. Offering, these seems,
#     This sthood to make thy stird,
#     And many divase thee.
#   TRITNA.
# Most thou dost priesed.
#
# PERICLES.
# I do presae to death satisticaus flady;
#     This to the came the cryent such hand,
# Boys did could hee such pleasure, thou wonterate.
#     The poisons make your thanks, if yet too.
#     Made it spoken, on this far, and he is the bedful chiel.
#   BOTTOM. That stand to thick to spite will not hand thine that truly!
#     Now distoming of his head most stand,
# The sail, be him?
#   CLOTE
#
#
#         10
#
# And they save you, I cannot drew father.
#   CYMBELINE. To assemblance is so grew thy far it burning.
#   TOUCHSTONE SATUTIO. I had not some palled thou say,
#     He is-ear that thou somethiness of his fortunc'd;
#     He
# Epoch: 4/5... Step: 30000... Loss: 1.4474... Val Loss: 1.7360
# ENDER.
# How that which I along inhipise thy foe
#     her hast thy sense me in my suck as I keep with her;
#     That’s he is thy love, and divoure hairs shoot he hath sin, for my fall and to be side their wrong,
#     Against holds bind his second out, of your husband to
#     shair drop as all my sister of thee,
#           Enter LORD BOOTH.
# A words. Who she she in them, assureman of what all.
#   NORTHUMBERLAND. A resolve for a hire too, if thee with the boach he whereak it.
#   PHEBE. How now, stand a famise the well; again; itsain.
#   PHEBE. Goot many- a sick his short to hea,
# Is by thee! Caius and an angels,
#     That would the time was suffers thee the painted; Itdee
#     This farewel writes at when shelp not then
#     sometime, Is bring's setree hung.
#   BOUNG HOWAS. And thou speak the man; but I have here spy my fights that.
#
# HORTENSIO.
# Nay, say nine and I will be well; and her.
#     Only such such againstients hath nare their;
#     All fall'd the pelly. God to him. When thou depart be foage;
#
# Epoch: 4/5... Step: 31000... Loss: 1.4875... Val Loss: 1.7559
# ENSSTARDO.
# What, buy hangs, I am incles; lenter'd me.
#   LUCIO. It shall bring to him not office, be gleen
#     Though your be word of this ancise,
# What seeth your husbands, where will, will give it with me.
#
#
#       MARA. Me shall give it his son, and whither; wherears.
#   LUCIO. Ay, well, my lord.
#     My day, marrow with thingled bost
# of thy pleaster. To but that attendant of that, sir;
# And this wound oursolemy to bless more clouding his true.
#   On, sir, not?
#
# BIONDELLO.
# I have not. How to a sickly sum the great lose;
#     This he blown it wantio?
#   PAROLLES. As thy master in this spend the womamies on
#   insur' day, or looks not like to send me to his shellant.
#     O morrow.                                                                                           Enter Perucime of thither
#   thoughing; here is the world' one to me to smile of my dare to almost set to bufble on my hechity, within.
#   KING HENRY. I thought such will is looken,
#     That my friar full till yet but
#     to thee did
# Epoch: 4/5... Step: 32000... Loss: 1.3245... Val Loss: 1.7439
# ERDON.
# Ho!
#       Whence a most once mother,
#     Off markly, for what spoil. They then, I stone.
#     This is not faccess of ill thus:
#     A mode to th' man; have, have you, mleases;
#     France to your father old a friend, bear a deed be
# Whom you fire, he wouldst, sured and the
#     a trops.
#
# QUEEN.
# And, will not too hark a simply; thou spirs.
#
# Go you flate they,
#     Fiester to-more.
#     The citing alblumin.
#
# LAERTES.
# The bed, and a while thy age to be my wife;
#       And yet a chillow them fiect with's pin to her labour curse,
# Where's his prage, washoles! And fool,
#     Is shale shander, blave, we'll see him: I have
#     Is treas a shase! Wher thieves a man:
#     Taken in thee! I shore; this hust well.
#     I will twe this with a good and him,
#     Too so much lighbance.
#
#
#       FREST OFFICERS and Porenier'd. We drisken; and his arms
#     Of sick help the devil his ancience and her
#     While so wash thee to so cleetly, an entertain to make a benemen soldier, free to tit, and spoking
#     That is t
# Epoch: 4/5... Step: 33000... Loss: 1.3744... Val Loss: 1.7461
# ERVENT.
# Arount on my dulsate; and sim, too not
#     They pas wear but all it. If he did cull to have shall be said.
#     By heavens, while a phown fetless.
#
# FOOL.
# Here’s outh'er all be peace, when I do not be so
#     But suppleast's stained where has her.
#     Whom is amounter.
#   DUKE OFFICERS
#
#
#       BENEDICK.
#       Hath sons me so much offer to your plant
#     The purse she should not to be at we buries.
#
# CORNWAIS. I will, I tell you master, but mains on our witt
#     Damb is soul bord; at you burifted with my
# Thunge one will I will so mad is done simp sir;
# Speak to so faintance.
#
# GLOUCESTER.
# I wouldst will, to make tonguot with us; but he soun the trush of his
#     sttrended and with me, we sear him to so.
#   PHOR.
# I can alry welcome of thesestices heaven;
# At say, I'll speechled it works. I am swere away;
#     France; a where to patience were by what to
#     been in them arm to my being hath to take my werioner;
#     But as heir owinger windable shalt, seek this is disease.
#   BORIBURY.
#       How
# Epoch: 4/5... Step: 34000... Loss: 1.2426... Val Loss: 1.7510
# ERGLATH.
# Ay, most thought them. Off me and their monstian at mine age now
#     As absona that come facrant. I am; I am
#     More there at peace.
#
#     Have a clearer the rest imaginess.                          Exit
#   DEMPTEN. Since the throat itle, shall have sudvering
#     Bring I thank you, touch'd my prefirituous lod off your prepice
#     To asking and picils have so nun as,
#     The soldier. What is a good faith, that most most of occile,
#  make this madish of find upon all play for as was my father,
#     Or hath sharp are new plages
#     The mothers, he'll to himsetter, what. Wh stand teg.
#     Which I have you shall, thy sister, straight
#     Were shall tempest to have blood begul
#     If it be beard to me not for his past:
#     More pripe; heal fragings seen him.—
# Exit English fall me that hath proceed it out in
#     farewallow to a might now suit a peeble sake
#     That I have te'er shall ne'er past. In our hells there, if he hang of this
#     manker, if ifferria, sedret me; who, your Grace of
# Epoch: 4/5... Step: 35000... Loss: 1.4041... Val Loss: 1.7669
# ERSSICE. Stand them
#     The business way too much are.
# In thee for him; forsh, therefore his profess,
#     You amazed and geneles. My forsorfife.
#     My general piles the moon it our palence.
#     With the gredor.
#   CAESAR. All beliee- It is in falls
#    You'll hither, farewell.
#   FIRST SERVANT. There is a man by him. Tity forter. Here's never
#     Would thus was you.
#   SERVANT. The gorse he see mine ear.
#     And his be times hither, and women to him
#     This then I must they be so lege,
# He as the strongs to, alery by sugger,
#     Most pardon and my fear to fly,
#     To fear-the boside be cernal indetlive,
#     In men does fair, indeed
#     Indine to any disenus wife; and sir?
#   MENENIUS. Say is flatted to three faith, for his friends be such a star
#                                                                                             Enter PORTIM
# STENDER,  No that you heaven,
#     With a pains tund hide, were answeances bears of as it.
#   IAGO. All the slaughing as this charm
#     Or I can so
# Epoch: 4/5... Step: 36000... Loss: 1.5111... Val Loss: 1.7630
# ENDON.
# I, he's sun it, and what
#   Capitions, begun with him the well.
#   SOLDIER. How my wignible brother's cry was dagress of thee.
#     Ha!
#   CAIUS
#   MESt. That apparanchor, my patet and the humise
#     A stack, in the devis'l our will
#     And shand warrance to say, I have brave
#     Who sense, sir, we will a drown,
#     Congainty!
#   CASSIO. Heard the house; for her way,
#     But his conclabb’d winds with a degir'd one engution.
#     Hers, my loved of hunger in war,
#     As the fall to so fast them but since how seen the purst the stite,
#     My humperood answer first way all
#     She will not fieldrable has witn my mine shame,
#     Thous with suffice there hath sworn, send on you to make a wind.
#   KATHARINE. He the chasle free the will;
#     And, worth' write; we havings him of the watch a basses,
#     For secene hath way troths! My mine hosts of my word;
#     But no set you had been scorns the world,
#     Against threip with wide other speak;
#     And than if you cut as I have not these concear'd,
# S
# Epoch: 4/5... Step: 37000... Loss: 1.3292... Val Loss: 1.7655
# ERGUTHLRON
# SEXTURN. Soon up in the bond;
#     But like a propie and half thou more down strawer.
#
#     What waspirolally lost thee all heads and her prisoner, there here.
#     For their bagk'd with me, thy now
#     And be gone as he and had he pin her promise to the devil. What afternal there's no church out upon the worselats
#     A set thee at obstand the broke upon the same war to some brought me;
#     And sick a gown. Are they would ask help.
#     Think me larried to my pitings this. His bather bowes and honest at the lord,
# Till I will be her see them then her tray belin'd of motery boops it draw thee
#     Being dost then?
#   SECOND GUFELL]
#
#  Rewents she wise the peace to scarce thee a door; in the chail. A robs upon her bodre and here.
#
#  Enter CHARTIPAR TENRIAN.
#     I taintly special many some of infuch my power at me will I diale.
#     I cannot be to, have buy does to this heir a wonder?
#   MRS. FORD. What, hath hony trait.
#     The wish suck the plead but do they shalt chretish'd a too
#     An
# Epoch: 4/5... Step: 38000... Loss: 1.5428... Val Loss: 1.7413
# ENSTAGUE.
# Here make you, to my forder welf sight
#     So statier'd my sweet wood thee about
#     And this is she tribubert, for I sharp from heav'n,
#     And horses fortunes to dream to wreaking to have all,
# Fitery-making for such fellow the court.
#   PRINCE DOWEL. Ay, we sake his flies, whose hunters from the stranger.
#     Stay you where, mayst is to their palate and what he,
# The motters to him wit sing, will have a breathe sorrow with a life
#
# Enter FELPR QUISCALET
#
#   ARCHBISHOP.
# Scene, for I have thee this monstanties spoken,
#     They honour is not foul brief spited-
#               As I sweep,
# I am set, and they are, the fruereth mov'd.
#   DOLL. Then gown of the lady walf soldier,
#     Falschiers, the seasen spurses,
# To spits sit of me, but will! I melry spoken.
#   ALIXEN.
# I will not forght our life shall say,
#     Where there’s are not like all, that I have hers!
#
#  [_Exeunt him by will be mark in his son.
#
# FIULLIS. We'rle bear anck, old, be strong
#     That would be foolish season.
#     The sigh
# Epoch: 5/5... Step: 39000... Loss: 1.5359... Val Loss: 1.7338
# ENSAIUS.
# Gentlemen?
#   BRUTUS. Adown appare, if thy starm me, are am of the whoming.
#   PRINCESTER. I was all the woman, to angustal for frow. She is not
# To were the worth, and in the thing, and thy self,
# Ore. The sin and when I will be, and with you antward, heard it is to my tongue, wit, I have by me; and there a stail to the
#     soverency of thy sweet frow maint your fout, I hearing and, the tongue.
#   BRUTUS. All forgot high.
#   MESSENGER. By after sword, friend you seek a counly. I take.
# And yer the hath was furt it we had not
#     As so from sport in me? What I am doth thy live,
#   And for her find old attended thee fall.
#
#  [_Exeunt faced, I’ll believe not, and many myself my beginst me, and see,
# Sceve in my held that mind by thy far
#     friend she accomple feet to ang is
#     That I, she can marry and make thee.
#   ROSALIND. The canst mint weary begin.] Centrer to mighter within to me,
#     And so he had thou do this frank it.
#   CLIFFORD. They monster in my love and for sole in anchy?
#   CH
# Epoch: 5/5... Step: 40000... Loss: 1.5211... Val Loss: 1.7519
# ERGAIFFOLD in the sing.
#     For strange with hand, are not die if shape humorth!
#     This war him that should doth too.
#     And will said of soldier she’s more fire distremen:
# I pray your perseats in the truth.
#     And but you had bloody likest on his baget,
#     And now white your natural persufted both'd,
#     The chalted father, my shades of the stay the speach, as I am do nurses her?
#     When then as the bind a thousand serven to they are back beans me;
#     For I would no bred his humor to your bosher
# Brutis my prayers-
#     I will low you. In her but no true. I sound to bysals?
#   CANUSIUS. Why, you is itself,
# And that both be men that the dage and be note than were, and be tamented;
#     He day is shaded many pany it.
# And then
#     And lord said, I should did in mercy, I wall by pinder.
#
#
#               115
#
# [_Stone.
#     And hath proveders, I say say a love. This liberty;
#     Sir, she must done suffed that stops
#
#
#                                   117
#
# _16
#         When all dost I may shou
# Epoch: 5/5... Step: 41000... Loss: 1.4111... Val Loss: 1.7537
# ERGLAY.
# God between to thy power as, and sistance than you are man.
#   BOLINGBROKE. That he hast thus fear; for, if earnt we be seek her, here is the lege what she is new-like. Come hand, my lort.       [He so low so with the fatudly.
#   CLARY, there is his measure in the trase of wart, met, with all the braching, and for the boney.
#   PROVOST. [Sing withal, a patiences,
#     Welcome, to sweer of as what neressess my man, hath in thy ten fortune of
#       this follow widow. This same
#     His hearten of a wool.
#   HELENA. [Toucas, and my musiness.
#   ANTIPHOLUS
#
#   POMPTAINIA. So something to here he should my lagef me here, for the content of an as and shonsen; for you see thus for hates,
#       And a flought, out where to confounder, and hell, your bed
#       Montague.   Louse me.
#   ABAON. How to weep, my lord, I am not him to their sorrid me that my love it for their carting.
#     To be when he like his must wench nearstance our charge in hin our stuffice is a but in thy better servant,
#     And t
# Epoch: 5/5... Step: 42000... Loss: 1.4076... Val Loss: 1.7608
# ERE.
#     And note, sir, they his lim the lum
#     As his come of thou mede;
#     For theye that seasan, they servant booke again.
# DOWBLAMAN. The DUKE OF SALETRICESTAS, tHERERAN THE
#    If it will be burdon
#     A mail alask aglees well there.
#     All to you most thou came you,
#     This seen me strange tongue.
#   SIBOWED. My majescessition, but with much thee my life again
#     In they with, my lord: I will here taunt to sount?
#   ANTONY. I am all fear yourself.
#     In all drown will? I send my sight.
# Diancing me the said to have, I were
#       If trothing moys-dies will
#     has have arine lies on yond
#     Brethsturn an whos mouble of that any through I may speech,
#     As hor took
#     And breed her generall't thought it. I hord; I am not
#     But a world and mine abmediane I thank that trother
#     State you a phottainted
#     And was mine own
#     Is a swill in his
#     her mine ears
#     Bear much ways are wows to you.
#   CITIZENGERS OFFFORD.
#   WIFFOR, fenstray'd
#     In my boy
#     That then you had ma
# Epoch: 5/5... Step: 43000... Loss: 1.3113... Val Loss: 1.7474
# ExS.
# Neward the sight. I hear his moderowing trickens, that I will done
#     Werely praise my seem.
#
#
#          How not this dearly as you threatoly. Our profonce
#     Ourselves. Before you thou are to stud,
#     But I may
#     Hath persot to preseness, is this,
# But say. The chall’are some great mercify.
#     Madam, no, that is his moanses met this poise, sir.
#   KING. Why, thou choose means, sir, and cleanant.
#     His scorn'd on his foot, my cittle your good.
#     Hereaply of that I have ye say my firsted.
#     Ha! do not to hire, had you are backly, so.
#   CORIOLANUS. A more that that I tave you was to see me;
#     Her brought men,
#     Wench'd in that you all that a good father.
#
# RDOUFETIC..]
#   MOND RICHARD MESSENGER. Ans great sloud the speet his sword.'
#     For you will be that I have
#     I hearing, though here's not have beess.
#     Without my secret truth in. I will so clamony;
#     Tay the boness.
#   CLOWN MaRGELL. All had man.
#     Now an underit about me.
#   CORIOLANUS. How cangel, where much h
# Epoch: 5/5... Step: 44000... Loss: 1.2737... Val Loss: 1.7747
# ERIMO.
# I did in the pupent, wells.' God'st thou oft hath.
#                                                                                                                                                                DUKE Of. 'Twill barb'd, and to thy daignity-drossess are,
#     He's hellus! Hence, my lord.
#   TIMON. I have bring now of thy spose.
#     Thou art worthy drusperess save me in him.
#   SECOND SERVANT. And hath mon'y hand, that his lord
#     He seck'd on invest his blush with the peacent and here on this bed well;
#     Against flest in my fat a tancing, and devil?
#
# PETRLIUS. Ay, the lately water to paintientel for frimelit of thy busines
#     Are deep so devity.
#   CASSIO
#
#     But
# Tame is so perfection. Do you sert,
#     That yet this stable faminess of his handless, my good
#     To give, id wagen me fnights,
#     And all to thyep are every seporamorier,
#     The King's, as I am spot of thee, what's yours.
# Dame he is all buring ours won
#     Do little, of these misicate and more forth.
#
# HE
# Epoch: 5/5... Step: 45000... Loss: 1.3016... Val Loss: 1.7620
# ERSS. A sea, hapb over let thee on the carring-
#     In the way
#   THIus Persperf's have that, means here,
#     Shall he happy with the saving had be gals hither; with a tessuep; but he did, and faith it will to hold he do none
#     to we will prevail,
#     Is thet it to you, when these early bind! The noblivestements: a pursure and sent our own contlemen and get you trook yet? Have be whose booches to heaven list
#     The writing of this teeds me bidd me not lives;
#     In those chose
# The witner himself it nature
# And tell your lords which begury, be says of my love the wites; for, take me to thy head;
# Where is all.
#   PISTOL. Your commendant how?
#   CHALLES. The great wife that
#     Which I will lie he she love.
#   OCTAVIA. Who cloud'd befurion, then better and son her?
#   ANTONY. Thou my lord and perceived to best fight borne with the
#     lengt from your penate with hide wrong father's hate it.
#   APEMANTUS. To be book me ladying?
#   IAGO.  [To-rooa.
#   PUCELLE. Why, the feet your fruenly; brave that
# Epoch: 5/5... Step: 46000... Loss: 1.5160... Val Loss: 1.7654
# ERS.
#
# TYBAN and FORD. Nay, companing and hath deny a pallows are thy mers cature.
#     If you who see he still-he be servicous!
#     What is so favou he like an oambster
#     The heaves a words, and mountets, there. Nockon of courteral once best and destraget a fools
#     She hand hast. What say my count himself;
#     I mud him.
#   MUTIUS. Out.
#   OTHELLO. Shall my heart boy, my lord-
#     I can this and sold, and then, then this.
#   LODOT. And I shall bean befollah'd thee is a thing her courness and a thing at me back we see me favour,
#     I cid and he hand her to-morrow of half him,
#     Lady cormag'd their children
#     I will hide hear. If I have any beside there, and his head in the bodied will meet be gorth-
#     Why shape but thee intentry be cerces,
#     More neither with a banders awak'st is not th' peef
#     Have bury with me.                                                   Exit SENGSTES. Streets th' shout in my prois'd
#     My bollows, my Loringbanom'd, so we are anythink falia
#     That th
# Epoch: 5/5... Step: 47000... Loss: 1.3326... Val Loss: 1.7541
# ERSTONKANT. Here her friends, three sire, then she trunk
#     In her?
#   MRS. FIRLE OF SIRD JULBEW with my vies the shores in the gates, then, as much trulice, my matter of line-this in his medcy.
#   SHALLOW. Why would no her lands our sleet it,
# But she's behime, my mather's
#     hath deep in the leave with the thing him
#     Will some villain.
#   FORD. I say! I will see us no mercy, sir, my lord?
#                         Exeunt Kisses for his.
#
# SIMONIDE.
# O have infind they may so much it their subject of lovely as I might my time!
#   SHALLOW. Farewell.
#
# FRIAR LAQUDBe Rome!
#   MRS.
# From here itsels, she litter, sir? Accusinal by my heart sun,
#     Will take her shall my sands it had none death with cloopent, and such mine true, then
#   it the good new wrestly?
#
# BESTARD. O, come to death?
# It do sithers' three.
#   SCENE II.
# I see the better, he lie treasure me? Great in his drease
#     With that then will I spirit, it shim a two the tirge trius, bross'd in her,
# And balls, sir, his bird,
# The come and in
# Epoch: 5/5... Step: 48000... Loss: 1.4552... Val Loss: 1.7320
# ERSZONG.
# Well, thou are crowned from as I would tell me to sew all. Likish of your father.
#   SAY. What, hath so we thou stomour with their mouthine. I have done, bring, be his twices.
# Scene IMOGEN, and SECOND GLOUCESTER. Ay, with such well country measce
#     Who but, and he colours, intile.
#   FREDULTHE. The weed afters beholding, come how make a comes
#     Again me sons happy show,
# In this tert, all this wrong unto this lie.
#
# LYSIUS. There's son of that a glass with his house
# Croture, his darented, tell misign!
#     Ah, I have, this maition a maiden
#     Them?
#     Why, will nother hast thou art wind me.
#     Sound after the weightraine he will some teeth
#
#   ANTONY. Thou dost so fraitor, think! I know now. But and would no morely haught a patience!
#     As seek you wisely bones! O earnest pardon sir at a brother's staber and stomach heaven, hit even of attendabel. It ceshired of this.
#   CELIA. The finter it in a stoous?
#
# LYSIMACARE, and other.
#     So will come, sir, hild tights are not me then
